# %%
## Import matplotlib and setup the figures to display within the notebook
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from numpy.random import randn, randint, uniform, sample

# %% [markdown]
# ## Line Plot

# %%
df = pd.DataFrame(randn(1000), index = pd.date_range('2019-06-07', periods=1000),
                  columns=['value'])

# %%
df.head(1)
# Out:
#                value
# 2019-06-07  0.018278

# %%
ts = pd.Series(randn(1000), index = pd.date_range('2019-06-07', periods=1000))
ts.head(5)
# Out:
# 2019-06-07    0.167806
# 2019-06-08    0.096454
# 2019-06-09   -1.017304
# 2019-06-10   -0.485497
# 2019-06-11    1.098683
# Freq: D, dtype: float64

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2019-06-07  0.018278
# 2019-06-08  0.821324
# 2019-06-09  1.344286
# 2019-06-10  0.071269
# 2019-06-11  0.450217

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07    0.167806
# 2019-06-08    0.264261
# 2019-06-09   -0.753044
# 2019-06-10   -1.238541
# 2019-06-11   -0.139857
# Freq: D, dtype: float64

# %%
# plot time series
ts.plot(figsize=(10,5));

# %%
# leagend appear because we plot dataframe
df.plot();

# %%
iris = sns.load_dataset('iris')

# %%
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
iris.plot(figsize=(10,5));

# %%
iris.plot(logx=True);

# %% [markdown]
# ## Line Plot 2

# %%
list(iris)
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# %%
y_1 = iris[['sepal_width', 'petal_width']]
x_1 = iris[['sepal_length', 'petal_length', 'species']]

# %%
x_1.head()
# Out:
#    sepal_length  petal_length species
# 0           5.1           1.4  setosa
# 1           4.9           1.4  setosa
# 2           4.7           1.3  setosa
# 3           4.6           1.5  setosa
# 4           5.0           1.4  setosa

# %%
x_1.describe()
# Out:
#        sepal_length  petal_length
# count    150.000000    150.000000
# mean       5.843333      3.758000
# std        0.828066      1.765298
# min        4.300000      1.000000
# 25%        5.100000      1.600000
# 50%        5.800000      4.350000
# 75%        6.400000      5.100000
# max        7.900000      6.900000

# %%
y_1.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
y_1.describe()
# Out:
#        sepal_width  petal_width
# count   150.000000   150.000000
# mean      3.057333     1.199333
# std       0.435866     0.762238
# min       2.000000     0.100000
# 25%       2.800000     0.300000
# 50%       3.000000     1.300000
# 75%       3.300000     1.800000
# max       4.400000     2.500000

# %%
# show x_1 and y_1 in different axes
# we replace the ax axis with ax and show x_1 in main y_axis and show y_1 in secondry axis

ax = x_1.plot()
y_1.plot(figsize=(10,5), ax=ax, secondary_y=True);

# %% [markdown]
# ## Bar Plot

# %%
df_1 = iris.drop(['species'], axis=1)

# %%
df_1.head(1)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2

# %%
df_1.iloc[0].plot(kind='bar');

# %%
df_1.iloc[0].plot.bar();

# %%
df_1.plot.bar();

# %%
df_1.plot.bar()

# %%
# plot the sum 
df_1.sum().plot.bar()

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head(1)
# Out:
#    survived  pclass   sex   age  ...  deck  embark_town  alive  alone
# 0         0       3  male  22.0  ...   NaN  Southampton     no  False
#
# [1 rows x 15 columns]

# %%
titanic['pclass'].value_counts().plot.bar()

# %%
titanic['survived'].value_counts().plot.bar()

# %% [markdown]
# ## Stacked Bar

# %%
df_2 = pd.DataFrame(randn(10,4), columns=['a', 'b', 'c', 'd'])
df_2.head()
# Out:
#           a         b         c         d
# 0  0.434978 -2.088882  0.644352  0.183051
# 1 -0.932665  0.493827  0.351595 -0.697250
# 2  0.415703 -0.904057  0.161445  0.537569
# 3  0.177903 -0.395655 -0.245107  0.492140
# 4  0.008809  1.022020  0.307062  0.682922

# %%
# show the percentage of each row
df_2.plot.bar(stacked = True);

# %%
df_2.plot.barh(stacked = True);

# %% [markdown]
# ## Histogram

# %%
iris.plot.hist();

# %%
iris.plot(kind='hist');

# %%
iris.plot(kind='hist', bins = 50);

# %%
# to show the overlabed
iris.plot(kind='hist', bins = 50, stacked=True);

# %%
# to show the overlabed
iris.plot(kind='hist', bins = 50, stacked=True, orientation = 'horizontal');

# %%
iris['petal_length'].plot.hist(bins=50);

# %%
df_1.diff().hist();

# %%
df_1.hist(color='r', alpha=0.8);

# %% [markdown]
# ## Box Plot

# %%
df_1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df_1.plot(kind= 'box', figsize=(10,5));

# %%
df_1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df_1.plot(kind= 'box', figsize=(10,5), vert=False);

# %% [markdown]
# ## Area and Scatter Plot

# %% [markdown]
# [Area Chart: Simple Definition, Examples](https://www.statisticshowto.com/area-chart/)
#
# *   An area chart is an extension of a line graph, where the area under the line is filled in. The “lines” are actually a series of points, connected by line segments. As well as looking slightly different from the run-of-the-mill line graph, area charts have different connotations; While a line graph measures change between points, an area chart emphasizes the data’s volume (Milne, 2003).

# %%
df_1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df_1.plot()

# %%
# it is stacked plot
df_1.plot(kind='area');

# %%
df_1.plot(kind='area', stacked =False, alpha=0.2);

# %% [markdown]
# ## Scatter Plot

# %%
df_1.plot.scatter(x='sepal_width', y='petal_width');

# %%
df_1.plot.scatter(x='sepal_width', y='petal_width', c='sepal_length');

# %%
ax = df_1.plot.scatter(x='sepal_width', y='petal_width', label='width');
df_1.plot.scatter(x='sepal_length', y='petal_length', ax=ax, color='r');

# %% [markdown]
# ## Hex and Pie Plot

# %%
df_1.plot.hexbin(x='sepal_length', y='petal_length', C='sepal_width', gridsize=20);

# %%
df_1.sum().plot(kind='pie', figsize=(10,5));

# %%
d = df_1.head(3).T
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
# create subplots for each row we have to T the dataset

d.plot.pie(subplots=True, figsize=(30,30), fontsize=14);
plt.show()

# %%
# create subplots for each row we have to T the dataset

d.plot.pie(subplots=True, figsize=(30,30), fontsize=14, autopct = '%.2f');
plt.show()

# %%
series = pd.Series([0.2]*4, index=['a', 'b', 'c', 'd'], name='Pie Plot' )

# %%
series
# Out:
# a    0.2
# b    0.2
# c    0.2
# d    0.2
# Name: Pie Plot, dtype: float64

# %%
# because the total is not 100%
series.plot.pie()
